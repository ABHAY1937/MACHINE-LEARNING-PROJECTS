# %% [markdown]
# <a href="https://colab.research.google.com/github/ABHAY1937/MACHINE-LEARNING-PROJECTS/blob/main/U_S_Wind_Turbine_Database_(USGS).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **U.S. WIND TURBINE DATABASE (USGS)**

# %% [markdown]
# ![unsplash-image-1024x683.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# The U.S. Wind Turbine Database is a comprehensive database of onshore wind turbines in the United States, which contains detailed information on the location, size, and specifications of individual wind turbines, as well as information on the wind farms and projects they are a part of.
#  The database includes turbines that are currently in operation, as well as those that have been retired or decommissioned, making it a valuable resource for analyzing the development and evolution of the wind energy industry in the United States.
# The USGS Wind Turbine Database can be used for a wide range of applications, such as site selection, energy planning, and environmental impact assessment, making it a valuable tool for advancing the development and deployment of renewable energy in the United States.
#
#
# source : https://eerscmap.usgs.gov/uswtdb/api-doc/

# %% [markdown]
# IMPLIMENTNG EDA LIBRARIES

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# FILTER OUT ANY FUTURE WARNINGS

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# IMPORTING THE ORGINAL FILE

# %%
df=pd.read_csv("/content/uswtdb_v5_3_20230113.csv")
df
# Out:
#        case_id t_state      t_county  t_fips                   p_name  p_year  \
# 0      3072695      CA   Kern County    6029                 251 Wind  1987.0
# 1      3072661      CA   Kern County    6029                 251 Wind  1987.0
# 2      3072704      CA   Kern County    6029                 251 Wind  1987.0
# 3      3063269      IA  Story County   19169  30 MW Iowa DG Portfolio  2017.0
# 4      3057059      IA  Story County   19169  30 MW Iowa DG Portfolio  2017.0
# ...        ...     ...           ...     ...                      ...     ...
# 72664  3126553      TX  Young County   48503     unknown Young County  2022.0
# 72665  3126296      TX  Young County   48503     unknown Young County  2022.0
# 72666  3040944      TX  Young County   48503   unknown Young County 1  2011.0
# 72667  3055917      CO   Yuma County    8125      unknown Yuma County  2016.0
# 72668  3055918      CO   Yuma County    8125      unknown Yuma County  2016.0
#
# ...

# %% [markdown]
# TOTAL NUMBER OF ROWS AND COLUMNS

# %%
df.shape
# Out:
# (72669, 13)

# %% [markdown]
# DATA TYPE

# %%
df.dtypes
# Out:
# case_id         int64
# t_state        object
# t_county       object
# t_fips          int64
# p_name         object
# p_year        float64
# p_tnum          int64
# retrofit        int64
# t_conf_atr      int64
# t_conf_loc      int64
# t_img_srce     object
# xlong         float64
# ylat          float64
# dtype: object

# %% [markdown]
# MISSING VALUES

# %%
df.isna().sum()
# Out:
# case_id         0
# t_state         0
# t_county        0
# t_fips          0
# p_name          0
# p_year        556
# p_tnum          0
# retrofit        0
# t_conf_atr      0
# t_conf_loc      0
# t_img_srce      0
# xlong           0
# ylat            0
# dtype: int64

# %% [markdown]
# TOTAL COLUMNS

# %%
df.columns
# Out:
# Index(['case_id', 't_state', 't_county', 't_fips', 'p_name', 'p_year',
#        'p_tnum', 'retrofit', 't_conf_atr', 't_conf_loc', 't_img_srce', 'xlong',
#        'ylat'],
#       dtype='object')

# %% [markdown]
# TOTAL INFORMATION

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72669 entries, 0 to 72668
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   case_id     72669 non-null  int64
#  1   t_state     72669 non-null  object
#  2   t_county    72669 non-null  object
#  3   t_fips      72669 non-null  int64
#  4   p_name      72669 non-null  object
#  5   p_year      72113 non-null  float64
#  6   p_tnum      72669 non-null  int64
#  7   retrofit    72669 non-null  int64
#  8   t_conf_atr  72669 non-null  int64
#  9   t_conf_loc  72669 non-null  int64
#  10  t_img_srce  72669 non-null  object
#  11  xlong       72669 non-null  float64
#  12  ylat        72669 non-null  float64
# dtypes: float64(3), int64(6), object(4)
# memory usage: 7.2+ MB

# %% [markdown]
# AFTER CLEANING THE FILE USING EXCEL :
# removed unwanted columns

# %%
df1=pd.read_csv("/content/uswtdb_v5_3_20230113...csv",encoding="latin-1", error_bad_lines=False, engine="python")
df1
# Out:
#        case_id t_state      t_county  t_fips                   p_name  p_year  \
# 0      3072695      CA   Kern County    6029                 251 Wind  1987.0
# 1      3072661      CA   Kern County    6029                 251 Wind  1987.0
# 2      3072704      CA   Kern County    6029                 251 Wind  1987.0
# 3      3063269      IA  Story County   19169  30 MW Iowa DG Portfolio  2017.0
# 4      3057059      IA  Story County   19169  30 MW Iowa DG Portfolio  2017.0
# ...        ...     ...           ...     ...                      ...     ...
# 72664  3126553      TX  Young County   48503     unknown Young County  2022.0
# 72665  3126296      TX  Young County   48503     unknown Young County  2022.0
# 72666  3040944      TX  Young County   48503   unknown Young County 1  2011.0
# 72667  3055917      CO   Yuma County    8125      unknown Yuma County  2016.0
# 72668  3055918      CO   Yuma County    8125      unknown Yuma County  2016.0
#
# ...

# %% [markdown]
# THE SIZE OF COLUMNS REDUCED TO 13

# %%
df1.shape
# Out:
# (72669, 13)

# %%
#columns
df1.columns
# Out:
# Index(['case_id', 't_state', 't_county', 't_fips', 'p_name', 'p_year',
#        'p_tnum', 'retrofit', 't_conf_atr', 't_conf_loc', 't_img_srce', 'xlong',
#        'ylat'],
#       dtype='object')

# %%
#missing values
df1.isna().sum()
# Out:
# case_id         0
# t_state         0
# t_county        0
# t_fips          0
# p_name          0
# p_year        556
# p_tnum          0
# retrofit        0
# t_conf_atr      0
# t_conf_loc      0
# t_img_srce      0
# xlong           0
# ylat            0
# dtype: int64

# %%
df1.dtypes
# Out:
# case_id         int64
# t_state        object
# t_county       object
# t_fips          int64
# p_name         object
# p_year        float64
# p_tnum          int64
# retrofit        int64
# t_conf_atr      int64
# t_conf_loc      int64
# t_img_srce     object
# xlong         float64
# ylat          float64
# dtype: object

# %% [markdown]
# CORRELATION

# %%
df1.corr()
# Out:
#              case_id    t_fips    p_year    p_tnum  retrofit  t_conf_atr  \
# case_id     1.000000  0.181117  0.610834 -0.156631  0.348245   -0.047809
# t_fips      0.181117  1.000000  0.288170 -0.168205  0.123520    0.106625
# p_year      0.610834  0.288170  1.000000 -0.409843 -0.130160    0.232966
# p_tnum     -0.156631 -0.168205 -0.409843  1.000000 -0.031955   -0.285808
# retrofit    0.348245  0.123520 -0.130160 -0.031955  1.000000   -0.017493
# t_conf_atr -0.047809  0.106625  0.232966 -0.285808 -0.017493    1.000000
# t_conf_loc -0.248179 -0.031126 -0.182169  0.043426  0.044806    0.231342
# xlong       0.116704  0.109196  0.320920 -0.247419 -0.026432    0.178059
# ylat       -0.089059 -0.258464 -0.037344 -0.151245 -0.028336    0.109443
#
#             t_conf_loc     xlong      ylat
# case_id      -0.248179  0.116704 -0.089059
# t_fips       -0.031126  0.109196 -0.258464
# p_year       -0.182169  0.320920 -0.037344
# p_tnum        0.043426 -0.247419 -0.151245
# ...

# %% [markdown]
# PLOTTING HEATMAP

# %%
sns.heatmap(df1.corr())
# Out:
# <Axes: >

# %% [markdown]
# FILLING THE MISSING COLUMN WITH MODE OF MOST REPEATED FREEQUENCY

# %%
## p_year :Year that the turbine became operational and began providing power
df1["p_year"]=df1["p_year"].mode()[0]

# %%
#DATA CLEANED
df1.isna().sum()
# Out:
# case_id       0
# t_state       0
# t_county      0
# t_fips        0
# p_name        0
# p_year        0
# p_tnum        0
# retrofit      0
# t_conf_atr    0
# t_conf_loc    0
# t_img_srce    0
# xlong         0
# ylat          0
# dtype: int64

# %% [markdown]
# COUNTING EACH COLUMNS ALSO VISUALIZE IT USING MATPLOTLIB , SEABORN

# %%
## t_state :State where turbine is located
df1["t_state"].value_counts()
# Out:
# TX    18586
# IA     6220
# CA     5974
# OK     5487
# KS     3962
# IL     3551
# CO     2834
# MN     2687
# ND     2134
# OR     2120
# NM     1952
# WA     1826
# MI     1631
# IN     1614
# NE     1541
# WY     1456
# SD     1411
# NY     1231
# MO     1174
# MT      803
# PA      751
# ID      541
# OH      499
# WI      451
# WV      419
# ME      417
# AZ      286
# UT      208
# AK      142
# HI      129
# NC      105
# MA       92
# NH       84
# MD       80
# VT       73
# NV       68
# PR       63
# RI       35
# TN       18
# NJ        6
# CT        3
# VA        2
# AR        1
# GU        1
# DE        1
# Name: t_state, dtype: int64

# %%
# Get the value counts of the column
counts = df1["t_state"].value_counts()

# Create a bar plot using Seaborn
sns.barplot(x=counts.index, y=counts.values)

# Set the plot title and axis labels
plt.title("Total count of turbine on each State")
plt.xlabel("State")
# Rotate the x-axis tick labels by 90 degrees
plt.xticks(rotation=90)
# Show the plot
plt.show()

# %%
## t_country :	County where turbine is located
df1["t_county"].value_counts()
# Out:
# Kern County          3466
# Nolan County         1411
# Lincoln County       1320
# Riverside County     1121
# Logan County          803
#                      ...
# Ogle County             1
# Nantucket County        1
# Bayamon Municipio       1
# Ceiba Municipio         1
# Richland County         1
# Name: t_county, Length: 569, dtype: int64

# %%
# Get the value counts of the column
counts = df1["t_county"].value_counts()

# Plot a histogram of the counts
plt.hist(counts.values)

# Set the plot title and axis labels
plt.title("Histogram of country value counts")
plt.xlabel("Value count")
plt.ylabel("Frequency")

# Show the plot
plt.show()

# %%
## t_fips :State and county fips where turbine is located, based on spatial join of turbine points with US state and county.
df1["t_fips"].value_counts()
# Out:
# 6029     3466
# 48353    1411
# 6065     1121
# 41021     735
# 48489     660
#          ...
# 26077       1
# 31159       1
# 39055       1
# 37189       1
# 6113        1
# Name: t_fips, Length: 694, dtype: int64

# %%
# Get the value counts of the column
counts = df1["t_fips"].value_counts()

# Create a bar plot using Seaborn
sns.barplot(x=counts.index, y=counts.values)

# Set the plot title and axis labels
plt.title("Value counts of t_fips column")
plt.xlabel("t_fips values")
# Rotate the x-axis tick labels by 90 degrees
plt.xticks(rotation=90)
# Show the plot
plt.show()

# %%
## p_name :Name of the wind power project that the turbine is a part
df1["p_name"].value_counts()
# Out:
# unknown Tehachapi Wind Resource Area 1    713
# Stateline Wind Project                    454
# Mesa Wind Farm                            432
# Western Spirit                            377
# Traverse Wind                             323
#                                          ...
# Gaines Cavern Wind Project                  1
# Mount St. Mary's Abbey                      1
# GobNob                                      1
# Golden Acorn Casino                         1
# Scituate Wind                               1
# Name: p_name, Length: 1736, dtype: int64

# %%
## p_year : Year that the turbine became operational and began providing power
df1["p_year"].value_counts()
# Out:
# 2012.0    72669
# Name: p_year, dtype: int64

# %%
## p_tnum :Number of turbines in the wind power project.
df1["p_tnum"].value_counts()
# Out:
# 100    4283
# 120    1802
# 66     1318
# 67     1136
# 75     1124
#        ...
# 11       89
# 549      25
# 210      18
# 232       8
# 194       3
# Name: p_tnum, Length: 185, dtype: int64

# %%
# Get the value counts of the column
counts = df1["p_tnum"].value_counts()

# Plot a histogram of the counts
plt.hist(counts.values)

# Set the plot title and axis labels
plt.title("Histogram of Number of turbine")
plt.xlabel("Value count")
plt.ylabel("Frequency")

# Show the plot
plt.show()

# %%
## retrofit :Indicator of whether the turbine has been partially retrofit after initial construction
##0 indicates no known retrofit. 1 indicates yes known retrofit.
df1["retrofit"].value_counts()
# Out:
# 0    65958
# 1     6711
# Name: retrofit, dtype: int64

# %%
# Get the value counts of the column
counts = df1["retrofit"].value_counts()

# Plot a pie chart of the counts
plt.pie(counts.values, labels=counts.index, autopct='%1.1f%%')

# Set the plot title
plt.title("Pie chart of retrofit value counts")

# Show the plot
plt.show()

# %%
## t_conf_atr :Level of confidence in the turbine attributes.
#1—No confidence: no attribute data beyond total height and year,
#2—Partial confidence: incomplete information or substantial conflict between,
#3—Full confidence: complete information, consistent across multiple data sources.
df1["t_conf_atr"].value_counts()
# Out:
# 3    64326
# 1     4604
# 2     3739
# Name: t_conf_atr, dtype: int64

# %%
# Get the value counts of the column
counts = df1["t_conf_atr"].value_counts()

# Plot a pie chart of the counts
plt.pie(counts.values, labels=counts.index, autopct='%1.1f%%')

# Set the plot title
plt.title("Pie chart of t_conf_atr value counts")

# Show the plot
plt.show()

# %%
##t_conf_loc :Level of confidence in turbine location.
##1— No turbine shown in image; image has clouds; imagery older than turbine built date,
# 2— Partial confidence: image shows a developed pad with concrete base and/or turbine parts on the ground,
# 3— Full confidence: image shows an installed turbine
value=df1["t_conf_loc"].value_counts()
value
# Out:
# 3    70373
# 1     2132
# 2      164
# Name: t_conf_loc, dtype: int64

# %%
# Create a bar plot using Seaborn
sns.barplot(x=value.index, y=value.values)

# Set the plot title and axis labels
plt.title("Value counts of t_conf_loc column")
plt.xlabel("t_conf_loc values")
# Rotate the x-axis tick labels by 90 degrees
plt.xticks(rotation=90)
# Show the plot
plt.show()

# %%
# t_img_srce :Source of image used to visually verify turbine location
data=df1["t_img_srce"].value_counts()
data
# Out:
# Digital Globe       57293
# Bing Maps Aerial     7942
# NAIP                 6712
# Google Earth          722
# Name: t_img_srce, dtype: int64

# %%
# Get the value counts of the column
counts = df1["t_img_srce"].value_counts()

# Create a bar plot using Seaborn
sns.barplot(x=counts.index, y=counts.values)

# Set the plot title and axis labels
plt.title("Value counts of t_img_srce column")
plt.xlabel("t_img_srce values")
# Rotate the x-axis tick labels by 90 degrees
plt.xticks(rotation=90)
# Show the plot
plt.show()

# %%
df1["xlong"].value_counts()
# Out:
# -116.582489    13
# -120.553185    12
# -116.587090    11
# -116.550087    11
# -116.591591    10
#                ..
# -97.575378      1
# -97.584435      1
# -97.599457      1
# -97.598595      1
# -102.716949     1
# Name: xlong, Length: 67058, dtype: int64

# %%
df1["ylat"].value_counts()
# Out:
# 37.644394    21
# 39.094994    14
# 37.577694    14
# 39.107094    14
# 39.085194    14
#              ..
# 45.790794     1
# 43.852291     1
# 45.809795     1
# 43.838390     1
# 40.037548     1
# Name: ylat, Length: 63858, dtype: int64

# %%
df1.dtypes
# Out:
# case_id         int64
# t_state        object
# t_county       object
# t_fips          int64
# p_name         object
# p_year        float64
# p_tnum          int64
# retrofit        int64
# t_conf_atr      int64
# t_conf_loc      int64
# t_img_srce     object
# xlong         float64
# ylat          float64
# dtype: object

# %%
sns.pairplot(df1,hue="t_state")

# %% [markdown]
# CREATE A DATAFRAME WITH CATEGORICAL VALUES USING GET_DUMMIES

# %%
df2=pd.get_dummies(df1[["t_state","t_county","p_name","t_img_srce"]],drop_first=True)

# %% [markdown]
# COMBINING THESE TWO DATASET

# %%
dfe=pd.concat([df1,df2],axis=1)

# %% [markdown]
# DROPPING UNWANTED COLUMNS

# %%
dfe.drop(columns=["t_state","t_county","p_name","t_img_srce","case_id"],axis=1,inplace=True)

# %%
dfe.columns
# Out:
# Index(['t_fips', 'p_year', 'p_tnum', 'retrofit', 't_conf_atr', 't_conf_loc',
#        'xlong', 'ylat', 't_state_AR', 't_state_AZ',
#        ...
#        'p_name_unknown Willacy County', 'p_name_unknown Williams County',
#        'p_name_unknown Woods County', 'p_name_unknown Wyoming County',
#        'p_name_unknown Young County', 'p_name_unknown Young County 1',
#        'p_name_unknown Yuma County', 't_img_srce_Digital Globe',
#        't_img_srce_Google Earth', 't_img_srce_NAIP'],
#       dtype='object', length=2358)

# %% [markdown]
# STRING REPRESENTATION OF DATAFRAME

# %%
str(dfe)
# Out:
# '       t_fips  p_year  p_tnum  retrofit  t_conf_atr  t_conf_loc       xlong  \\\n0        6029  2012.0     194         0           2           3 -118.364410   \n1        6029  2012.0     194         0           2           3 -118.363762   \n2        6029  2012.0     194         0           2           3 -118.364197   \n3       19169  2012.0      10         0           3           3  -93.632835   \n4       19169  2012.0      10         0           3           3  -93.623009   \n...       ...     ...     ...       ...         ...         ...         ...   \n72664   48503  2012.0      61         0           1           3  -98.858994   \n72665   48503  2012.0      61         0           1           3  -98.866684   \n72666   48503  2012.0       1         0           1           3  -98.551094   \n72667    8125  2012.0       2         0           1           3 -102.717171   \n72668    8125  2012.0       2         0           1           3 -102.716949   \n\n            ylat  t_state_AR  t_st
# ...

# %% [markdown]
# CONVERTING OBJECT TO FLOAT

# %%
dfe["p_tnum"]=dfe["p_tnum"].astype(float)
dfe["retrofit"]=dfe["retrofit"].astype(float)
dfe["t_conf_atr"]=dfe["t_conf_atr"].astype(float)
dfe["t_conf_loc"]=dfe["t_conf_loc"].astype(float)
dfe["xlong"]=dfe["xlong"].astype(float)
dfe["ylat"]=dfe["ylat"].astype(float)
dfe["t_img_srce_Digital Globe"]=dfe["t_img_srce_Digital Globe"].astype(float)
dfe["t_img_srce_NAIP"]=dfe["t_img_srce_NAIP"].astype(float)
dfe["t_img_srce_Digital Globe"]=dfe["t_img_srce_Digital Globe"].astype(float)
dfe["p_year"]=dfe["p_year"].astype(float)
dfe["t_fips"]=dfe["t_fips"].astype(float)

# %% [markdown]
# CONVERTING INT OR FLOAT TO NaN

# %%
dfe.loc[dfe.p_tnum==0, "p_tnum"]=np.NaN
dfe.loc[dfe.retrofit==0, "retrofit"]=np.NaN
dfe.loc[dfe.t_conf_atr==0, "t_conf_atr"]=np.NaN
dfe.loc[dfe.t_conf_loc==0, "t_conf_loc"]=np.NaN
dfe.loc[dfe.xlong==0, "xlong"]=np.NaN
dfe.loc[dfe.ylat==0, "ylat"]=np.NaN
dfe.loc[dfe.p_year==0, "p_year"]=np.NaN

# %% [markdown]
# HANDLING MISSING VALUES

# %%
dfe["p_tnum"]=dfe["p_tnum"].fillna(dfe["p_tnum"].mean())
dfe["retrofit"]=dfe["retrofit"].fillna(dfe["retrofit"].mean())
dfe["t_conf_atr"]=dfe["t_conf_atr"].fillna(dfe["t_conf_atr"].mean())
dfe["t_conf_atr"]=dfe["t_conf_atr"].fillna(dfe["t_conf_atr"].mean())
dfe["xlong"]=dfe["xlong"].fillna(dfe["xlong"].mean())
dfe["ylat"]=dfe["ylat"].fillna(dfe["ylat"].mean())

# %% [markdown]
# TOTAL INFORMATION

# %%
dfe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72669 entries, 0 to 72668
# Columns: 2358 entries, t_fips to t_img_srce_NAIP
# dtypes: float64(10), uint8(2348)
# memory usage: 168.3 MB

# %%
#Re-checking any obj value present or not
dfe.select_dtypes(include='object').columns
# Out:
# Index([], dtype='object')

# %%
dfe.isna()
# Out:
#        t_fips  p_year  p_tnum  retrofit  t_conf_atr  t_conf_loc  xlong   ylat  \
# 0       False   False   False     False       False       False  False  False
# 1       False   False   False     False       False       False  False  False
# 2       False   False   False     False       False       False  False  False
# 3       False   False   False     False       False       False  False  False
# 4       False   False   False     False       False       False  False  False
# ...       ...     ...     ...       ...         ...         ...    ...    ...
# 72664   False   False   False     False       False       False  False  False
# 72665   False   False   False     False       False       False  False  False
# 72666   False   False   False     False       False       False  False  False
# 72667   False   False   False     False       False       False  False  False
# 72668   False   False   False     False       False       False  False  False
#
# ...

# %%
nan_cols = dfe.any()
nan_cols
# Out:
# t_fips                           True
# p_year                           True
# p_tnum                           True
# retrofit                         True
# t_conf_atr                       True
#                                  ...
# p_name_unknown Young County 1    True
# p_name_unknown Yuma County       True
# t_img_srce_Digital Globe         True
# t_img_srce_Google Earth          True
# t_img_srce_NAIP                  True
# Length: 2358, dtype: bool

# %%
cols_with_nan = dfe.columns[nan_cols]
cols_with_nan
# Out:
# Index(['t_fips', 'p_year', 'p_tnum', 'retrofit', 't_conf_atr', 't_conf_loc',
#        'xlong', 'ylat', 't_state_AR', 't_state_AZ',
#        ...
#        'p_name_unknown Willacy County', 'p_name_unknown Williams County',
#        'p_name_unknown Woods County', 'p_name_unknown Wyoming County',
#        'p_name_unknown Young County', 'p_name_unknown Young County 1',
#        'p_name_unknown Yuma County', 't_img_srce_Digital Globe',
#        't_img_srce_Google Earth', 't_img_srce_NAIP'],
#       dtype='object', length=2358)

# %%
dfe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72669 entries, 0 to 72668
# Columns: 2358 entries, t_fips to t_img_srce_NAIP
# dtypes: float64(10), uint8(2348)
# memory usage: 168.3 MB

# %%
dfe.dtypes
# Out:
# t_fips                           float64
# p_year                           float64
# p_tnum                           float64
# retrofit                         float64
# t_conf_atr                       float64
#                                   ...
# p_name_unknown Young County 1      uint8
# p_name_unknown Yuma County         uint8
# t_img_srce_Digital Globe         float64
# t_img_srce_Google Earth            uint8
# t_img_srce_NAIP                  float64
# Length: 2358, dtype: object

# %%
dfe.isna().sum()
# Out:
# t_fips                           0
# p_year                           0
# p_tnum                           0
# retrofit                         0
# t_conf_atr                       0
#                                 ..
# p_name_unknown Young County 1    0
# p_name_unknown Yuma County       0
# t_img_srce_Digital Globe         0
# t_img_srce_Google Earth          0
# t_img_srce_NAIP                  0
# Length: 2358, dtype: int64

# %%
#adding a new name to the current variable
x=dfe

# %%
#rechecking any obj present
a=np.isnan(x)

if np.any(a):
  print(np.where(a)[0])

# %% [markdown]
# K-MEANS CLUSTER

# %%
from sklearn.cluster import KMeans
import time

start_time = time.time()
kmeans = KMeans(n_clusters=2, n_init=10)
wcss = []
for i in range(1, 21): # reduce range of clusters to test
  kmeans = KMeans(n_clusters=i, init='k-means++', n_init=5, max_iter=100, random_state=42) # reduce n_init and max_iter
  kmeans.fit(x)
  wcss.append(kmeans.inertia_)

# %%
#TIME TAKEN FOR EXCECUTING THE CODE
print("--- Execution time: %s seconds ---" % (time.time() - start_time))
# Out:
# --- Execution time: 663.8495900630951 seconds ---

# %%
print(wcss)
# Out:
# [17276273708546.52, 3362713963038.5127, 1782384621119.5327, 736448070005.5732, 327517801777.3489, 178397260000.44434, 125991588350.3016, 96699330359.95097, 77912803097.46552, 68298131832.95206, 51326032357.29924, 48527217787.89929, 32399522222.222023, 25636933275.501514, 21254897198.613247, 17136421625.043896, 14517206292.467953, 13347252816.197638, 9337671868.04212, 7668832468.622519]

# %% [markdown]
# ELBOW-POINT

# %%
import matplotlib.pyplot as plt

plt.plot(range(1,21),wcss)
plt.xlabel("cluster")
plt.ylabel("varients")
plt.title("elbow point graph")
plt.show()

# %%
Kmeans=KMeans(n_clusters=4,init='k-means++',random_state=42)
y_pred=Kmeans.fit_predict(x)
y_pred
# Out:
# array([3, 3, 3, ..., 2, 3, 3], dtype=int32)

# %% [markdown]
# PREDICTED VALUE

# %%
x["cluster"]=y_pred
x
# Out:
#         t_fips  p_year  p_tnum  retrofit  t_conf_atr  t_conf_loc       xlong  \
# 0       6029.0  2012.0   194.0       1.0         2.0         3.0 -118.364410
# 1       6029.0  2012.0   194.0       1.0         2.0         3.0 -118.363762
# 2       6029.0  2012.0   194.0       1.0         2.0         3.0 -118.364197
# 3      19169.0  2012.0    10.0       1.0         3.0         3.0  -93.632835
# 4      19169.0  2012.0    10.0       1.0         3.0         3.0  -93.623009
# ...        ...     ...     ...       ...         ...         ...         ...
# 72664  48503.0  2012.0    61.0       1.0         1.0         3.0  -98.858994
# 72665  48503.0  2012.0    61.0       1.0         1.0         3.0  -98.866684
# 72666  48503.0  2012.0     1.0       1.0         1.0         3.0  -98.551094
# 72667   8125.0  2012.0     2.0       1.0         1.0         3.0 -102.717171
# 72668   8125.0  2012.0     2.0       1.0         1.0         3.0 -102.716949
#
# ...

# %%
y_pred
# Out:
# array([3, 3, 3, ..., 2, 3, 3], dtype=int32)

# %%
x.isna().sum()
# Out:
# t_fips                        0
# p_year                        0
# p_tnum                        0
# retrofit                      0
# t_conf_atr                    0
#                              ..
# p_name_unknown Yuma County    0
# t_img_srce_Digital Globe      0
# t_img_srce_Google Earth       0
# t_img_srce_NAIP               0
# cluster                       0
# Length: 2359, dtype: int64

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72669 entries, 0 to 72668
# Columns: 2359 entries, t_fips to cluster
# dtypes: float64(10), int32(1), uint8(2348)
# memory usage: 168.5 MB

# %% [markdown]
# VARIABLE SEPERATION USING i.loc

# %%
a=x.iloc[:,:-1].values
b=x.iloc[:,-1].values

# %% [markdown]
# DATA TRAINING AND TESTING

# %%
from sklearn.model_selection import train_test_split
a_train ,a_test,b_train,b_test =train_test_split(a,b,test_size=0.30,random_state=42)
a_train.shape
# Out:
# (50868, 2358)

# %%
a_test.shape
# Out:
# (21801, 2358)

# %% [markdown]
# DATA PREPROCESSING

# %%
from sklearn.preprocessing import StandardScaler
scalar=StandardScaler()
scalar.fit(a_train)
a_train=scalar.fit_transform(a_train)
a_test=scalar.fit_transform(a_test)

# %% [markdown]
# IMPLIMENTING SUPPORT VECTOR MACHINE ALGORITHM

# %%
#model selection
from sklearn.svm import SVC
model=SVC()
model.fit(a_train,b_train)
# Out:
# SVC()

# %%
ypred=model.predict(a_test)
ypred
# Out:
# array([2, 2, 1, ..., 2, 2, 2], dtype=int32)

# %% [markdown]
# ACCURACY SCORE

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
score=accuracy_score(b_test,ypred)
score
# Out:
# 0.9925232787486813

# %% [markdown]
# classification report

# %%
report=classification_report(b_test,ypred)
report
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      0.99      1.00      5418\n           1       0.97      1.00      0.99      6119\n           2       1.00      0.99      1.00      7509\n           3       1.00      0.98      0.99      2755\n\n    accuracy                           0.99     21801\n   macro avg       0.99      0.99      0.99     21801\nweighted avg       0.99      0.99      0.99     21801\n'

# %% [markdown]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      5418
#            1       0.97      1.00      0.99      6119
#            2       1.00      0.99      1.00      7509
#            3       1.00      0.98      0.99      2755
#
#     accuracy                           0.99     21801
#    macro avg       0.99      0.99      0.99     21801
# weighted avg       0.99      0.99      0.99     21801

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,ConfusionMatrixDisplay
result=confusion_matrix(b_test,ypred)
labels=[0,1,2,3]
cmd=ConfusionMatrixDisplay(result,display_labels=labels)
cmd.plot()

# %% [markdown]
# IMPLIMENTING K-NEAREST NEIGHBOR ALGORITHM

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=7) #k=7
model.fit(a_train,b_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
ypred=model.predict(a_test)
ypred
# Out:
# array([2, 2, 1, ..., 2, 2, 2], dtype=int32)

# %% [markdown]
# ACCURACY SCORE

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
score=accuracy_score(b_test,ypred)
score
# Out:
# 0.9894041557726709

# %% [markdown]
# classification report

# %%
report=classification_report(b_test,ypred)
report
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      0.99      1.00      5418\n           1       1.00      0.98      0.99      6119\n           2       1.00      0.99      1.00      7509\n           3       0.92      1.00      0.96      2755\n\n    accuracy                           0.99     21801\n   macro avg       0.98      0.99      0.99     21801\nweighted avg       0.99      0.99      0.99     21801\n'

# %% [markdown]
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      5418
#            1       1.00      0.98      0.99      6119
#            2       1.00      0.99      1.00      7509
#            3       0.92      1.00      0.96      2755
#
#     accuracy                           0.99     21801
#    macro avg       0.98      0.99      0.99     21801
# weighted avg       0.99      0.99      0.99     21801

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,ConfusionMatrixDisplay
result=confusion_matrix(b_test,ypred)
labels=[0,1,2,3]
cmd=ConfusionMatrixDisplay(result,display_labels=labels)
cmd.plot()

# %% [markdown]
# IMPLIMENTING DECISION TREE ALGORITHM

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier(criterion="entropy")
model.fit(a_train,b_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
ypred=model.predict(a_test)
ypred
# Out:
# array([2, 2, 1, ..., 2, 2, 2], dtype=int32)

# %% [markdown]
# ACCURACY SCORE

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
score=accuracy_score(b_test,ypred)
score
# Out:
# 1.0

# %% [markdown]
# classification report

# %%
report=classification_report(b_test,ypred)
report
# Out:
# '              precision    recall  f1-score   support\n\n           0       1.00      1.00      1.00      5418\n           1       1.00      1.00      1.00      6119\n           2       1.00      1.00      1.00      7509\n           3       1.00      1.00      1.00      2755\n\n    accuracy                           1.00     21801\n   macro avg       1.00      1.00      1.00     21801\nweighted avg       1.00      1.00      1.00     21801\n'

# %% [markdown]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5418
#            1       1.00      1.00      1.00      6119
#            2       1.00      1.00      1.00      7509
#            3       1.00      1.00      1.00      2755
#
#     accuracy                           1.00     21801
#    macro avg       1.00      1.00      1.00     21801
# weighted avg       1.00      1.00      1.00     21801

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,ConfusionMatrixDisplay
result=confusion_matrix(b_test,ypred)
labels=[0,1,2,3]
cmd=ConfusionMatrixDisplay(result,display_labels=labels)
cmd.plot()

# %% [markdown]
# IMPLIMENTING RANDOM FOREST ALGORITHM

# %%
#model creation
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(max_depth=2)
model.fit(a_train,b_train)
# Out:
# RandomForestClassifier(max_depth=2)

# %%
ypred=model.predict(a_test)
ypred
# Out:
# array([2, 2, 1, ..., 2, 2, 2], dtype=int32)

# %% [markdown]
#  ACCURACY SCORE

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
score=accuracy_score(b_test,ypred)
score
# Out:
# 0.7239117471675611

# %% [markdown]
# classification report

# %%
report=classification_report(b_test,ypred)
report
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
#               precision    recall  f1-score   support
#
#            0       1.00      0.41      0.58      5418
#            1       0.88      0.99      0.93      6119
#            2       0.59      1.00      0.74      7509
#            3       0.00      0.00      0.00      2755
#
#     accuracy                           0.72     21801
#    macro avg       0.62      0.60      0.56     21801
# weighted avg       0.70      0.72      0.66     21801

# %%
#displaying confusion matrix hrough grapically
from sklearn.metrics import confusion_matrix,accuracy_score,ConfusionMatrixDisplay
result=confusion_matrix(b_test,ypred)
labels=[0,1,2,3]
cmd=ConfusionMatrixDisplay(result,display_labels=labels)
cmd.plot()
